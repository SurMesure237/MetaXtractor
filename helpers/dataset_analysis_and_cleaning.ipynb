# %% [markdown]
# # NER Dataset Analysis and Cleaning
#
# This notebook analyzes and cleans the annotated NER dataset to:
# - Check label formations and patterns
# - Analyze label distribution
# - Identify potential overfitting issues
# - Balance the dataset
# - Provide tools for label deletion

# %% [markdown]
# ## 1. Installation and Dependencies

# %%
# Install required packages
# !pip install pandas numpy matplotlib seaborn scikit-learn --quiet
# Out:
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## 2. Import Libraries and Setup Logging

# %%
import json
import logging
from pathlib import Path
from collections import Counter, defaultdict
from typing import Dict, List, Tuple

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Setup logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s'
)
logger = logging.getLogger(__name__)

# Set style for plots
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# ## 3. Load Dataset

# %%
# Path to dataset
DATASET_PATH = Path('../data/dataset/full/dataset.json')

def load_dataset(path: Path) -> List[Dict]:
    """Load the annotated dataset."""
    logger.info(f"Loading dataset from {path}")
    with open(path, 'r', encoding='utf-8') as f:
        data = json.load(f)
    logger.info(f"Loaded {len(data)} samples")
    return data

dataset = load_dataset(DATASET_PATH)
# Out:
# 2025-11-17 01:38:04,877 - INFO - Loading dataset from ../data/dataset/full/dataset.json
# 2025-11-17 01:38:04,933 - INFO - Loaded 2238 samples

# %% [markdown]
# ## 4. Extract Annotations

# %%
def extract_annotations(dataset: List[Dict]) -> List[Dict]:
    """Extract all annotations from the dataset."""
    annotations = []
    
    for sample in dataset:
        sample_id = sample['id']
        sample_project = sample.get('data', []).get('repo', 'unknown')
        text = sample['data'].get('text', '')
        
        for annotation in sample.get('annotations', []):
            if annotation.get('was_cancelled', False):
                continue
                
            for result in annotation.get('result', []):
                if result.get('type') == 'labels':
                    value = result['value']
                    annotations.append({
                        'project': sample_project,
                        'sample_id': sample_id,
                        'text': value['text'],
                        'label': value['labels'][0],
                        'start': value['start'],
                        'end': value['end'],
                        'length': len(value['text']),
                        'source_text': text
                    })
    
    logger.info(f"Extracted {len(annotations)} annotations")
    return annotations

annotations = extract_annotations(dataset)
df_annotations = pd.DataFrame(annotations)

logger.info(f"Total annotations: {len(df_annotations)}")
logger.info(f"Unique labels: {df_annotations['label'].nunique()}")
df_annotations.head()
# Out:
# 2025-11-17 01:38:06,938 - INFO - Extracted 2935 annotations
# 2025-11-17 01:38:06,944 - INFO - Total annotations: 2935
# 2025-11-17 01:38:06,946 - INFO - Unique labels: 17
#                     project  sample_id       text                  label  \
# 0  455_Citation_File_Format       2712  CC-BY-4.0                LICENSE
# 1  455_Citation_File_Format       2713        MIT                LICENSE
# 2  455_Citation_File_Format       2713  CC-BY-4.0                LICENSE
# 3  455_Citation_File_Format       2713    CC0-1.0                LICENSE
# 4  455_Citation_File_Format       2713     pandas  SOFTWARE_REQUIREMENTS
#
#    start   end  length                                        source_text
# 0     25    34       9  SPDX-License-Identifier: CC-BY-4.0 -->\n\n:war...
# 1   1412  1415       3  cfftracker\n\nTracks CITATION.cff files across...
# 2   1467  1476       9  cfftracker\n\nTracks CITATION.cff files across...
# 3   1517  1524       7  cfftracker\n\nTracks CITATION.cff files across...
# 4   1100  1106       6  cfftracker\n\nTracks CITATION.cff files across...

# %% [markdown]
# ## 5. Label Distribution Analysis

# %%
def analyze_label_distribution(df: pd.DataFrame) -> pd.DataFrame:
    """Analyze the distribution of labels in the dataset."""
    label_counts = df['label'].value_counts()
    label_stats = pd.DataFrame({
        'count': label_counts,
        'percentage': (label_counts / len(df) * 100).round(2)
    })
    
    logger.info("\nLabel Distribution:")
    for label, row in label_stats.iterrows():
        logger.info(f"{label}: {row['count']} ({row['percentage']}%)")
    
    return label_stats

label_stats = analyze_label_distribution(df_annotations)
label_stats
# Out:
# 2025-11-17 01:38:10,580 - INFO -
# Label Distribution:
# 2025-11-17 01:38:10,581 - INFO - SOFTWARE_REQUIREMENTS: 789.0 (26.88%)
# 2025-11-17 01:38:10,582 - INFO - SOFTWARE_REQUIREMENTS_URL: 274.0 (9.34%)
# 2025-11-17 01:38:10,582 - INFO - OPERATING_SYSTEM: 249.0 (8.48%)
# 2025-11-17 01:38:10,583 - INFO - CITATION_URL: 240.0 (8.18%)
# 2025-11-17 01:38:10,583 - INFO - DOCUMENTATION_URL: 230.0 (7.84%)
# 2025-11-17 01:38:10,584 - INFO - LICENSE: 211.0 (7.19%)
# 2025-11-17 01:38:10,584 - INFO - CITATION: 159.0 (5.42%)
# 2025-11-17 01:38:10,584 - INFO - LICENSE_URL: 138.0 (4.7%)
# 2025-11-17 01:38:10,585 - INFO - REFERENCE_PUBLICATION: 133.0 (4.53%)
# 2025-11-17 01:38:10,585 - INFO - SOFTWARE_REQUIREMENTS_VERSION: 112.0 (3.82%)
# 2025-11-17 01:38:10,586 - INFO - RUNTIME_PLATFORM: 102.0 (3.48%)
# 2025-11-17 01:38:10,586 - INFO - REFERENCE_PUBLICATION_URL: 75.0 (2.56%)
# 2025-11-17 01:38:10,587 - INFO - BUILD_INSTRUCTIONS: 69.0 (2.35%)
# 2025-11-17 01:38:10,587 - INFO - CITATION_BIBTEX: 62.0 (2.11%)
# 2025-11-17 01:38:10,588 - INFO - RELATED_LINK: 50.0 (1.7%)
# 2025-11-17 01:38:10,588 - INFO - CONTINUOUS_INTEGRATION: 38.0 (1.29%)
# 2025-11-17 01:38:10,589 - INFO - REFERENCE_PUBLICATION_BIBTEX: 4.0 (0.14%)
#                                count  percentage
# label
# SOFTWARE_REQUIREMENTS            789       26.88
# SOFTWARE_REQUIREMENTS_URL        274        9.34
# OPERATING_SYSTEM                 249        8.48
# CITATION_URL                     240        8.18
# DOCUMENTATION_URL                230        7.84
# LICENSE                          211        7.19
# CITATION                         159        5.42
# LICENSE_URL                      138        4.70
# REFERENCE_PUBLICATION            133        4.53
# SOFTWARE_REQUIREMENTS_VERSION    112        3.82
# RUNTIME_PLATFORM                 102        3.48
# REFERENCE_PUBLICATION_URL         75        2.56
# BUILD_INSTRUCTIONS                69        2.35
# CITATION_BIBTEX                   62        2.11
# RELATED_LINK                      50        1.70
# CONTINUOUS_INTEGRATION            38        1.29
# REFERENCE_PUBLICATION_BIBTEX       4        0.14

# %%
def load_labelstudio_data(file_path: str) -> List[Dict]:
    """Load Label Studio exported JSON dataset."""
    with open(file_path, 'r', encoding='utf-8') as f:
        data = json.load(f)
    logger.info(f"Loaded {len(data)} tasks from {file_path}")
    return data

raw_data = load_labelstudio_data(DATASET_PATH)

# Cell 3: Extract Entities and Analyze Label Distribution
def extract_entities(data: List[Dict]) -> Tuple[List[Dict], Dict[str, int]]:
    """Extract texts and their entities, return list of {'text': str, 'entities': list} and label counts."""
    processed_data = []
    label_counts = Counter()

    for task in data:
        text = task['data']['text']
        entities = []

        if 'annotations' in task and task['annotations']:
            for ann in task['annotations'][0].get('result', []):
                if 'value' in ann:
                    val = ann['value']
                    entities.append({
                        'start': val['start'],
                        'end': val['end'],
                        'label': val['labels'][0],
                        'text': val['text']
                    })
                    label_counts[val['labels'][0]] += 1

        processed_data.append({'text': text, 'entities': entities})

    logger.info(f"Processed {len(processed_data)} documents with {sum(len(d['entities']) for d in processed_data)} entities")
    return processed_data, dict(label_counts)

processed_data, label_counts = extract_entities(raw_data)

# Visualize label distribution with counts on bars
df_labels = pd.DataFrame(list(label_counts.items()), columns=['Label', 'Count']).sort_values('Count', ascending=False)
plt.figure(figsize=(12, 6))
ax = sns.barplot(x='Count', y='Label', data=df_labels)
plt.title('Label Distribution')

# Add count labels to each bar
for i, (count, label) in enumerate(zip(df_labels['Count'], df_labels['Label'])):
    ax.text(count + 0.02 * max(df_labels['Count']),
            i,
            str(count),
            va='center', ha='left', fontsize=10)

plt.tight_layout()
plt.show()

logger.info(f"Label counts:\n{df_labels.to_string(index=False)}")
logger.info(f"Unique labels: {len(label_counts)}")
min_count, max_count = df_labels['Count'].min(), df_labels['Count'].max()
logger.info(f"Min/Max counts: {min_count}/{max_count} - Imbalance ratio: {max_count/min_count:.2f}")
# Out:
# 2025-11-17 01:38:14,329 - INFO - Loaded 2238 tasks from ../data/dataset/full/dataset.json
# 2025-11-17 01:38:14,334 - INFO - Processed 2238 documents with 3017 entities
# 2025-11-17 01:38:14,449 - INFO - Label counts:
#                         Label  Count
#         SOFTWARE_REQUIREMENTS    824
#     SOFTWARE_REQUIREMENTS_URL    274
#              OPERATING_SYSTEM    266
#                  CITATION_URL    243
#             DOCUMENTATION_URL    230
#                       LICENSE    220
#                      CITATION    161
#                   LICENSE_URL    139
#         REFERENCE_PUBLICATION    133
# SOFTWARE_REQUIREMENTS_VERSION    112
#              RUNTIME_PLATFORM    110
#     REFERENCE_PUBLICATION_URL     75
#            BUILD_INSTRUCTIONS     73
#               CITATION_BIBTEX     62
#                  RELATED_LINK     51
#        CONTINUOUS_INTEGRATION     40
#  REFERENCE_PUBLICATION_BIBTEX      4
# 2025-11-17 01:38:14,449 - INFO - Unique labels: 17
# 2025-11-17 01:38:14,450 - INFO - Min/Max counts: 4/824 - Imbalance ratio: 206.00

# %%
# Visualize label distribution with improved readability
fig, ax = plt.subplots(figsize=(18, 10))

# Bar plot with better formatting
label_stats['count'].plot(kind='bar', ax=ax, color='steelblue', width=0.7)
ax.set_title('Label Distribution (Count)', fontsize=18, fontweight='bold', pad=20)
ax.set_xlabel('Label', fontsize=15, fontweight='bold')
ax.set_ylabel('Count', fontsize=15, fontweight='bold')
ax.set_xticklabels(label_stats.index, rotation=45, ha='right', fontsize=12)
ax.tick_params(axis='y', labelsize=13)
ax.grid(axis='y', alpha=0.3, linestyle='--')

# Add value labels on top of bars
for i, v in enumerate(label_stats['count']):
    ax.text(i, v + max(label_stats['count']) * 0.01, str(v), 
            ha='center', va='bottom', fontsize=11, fontweight='bold')

plt.tight_layout()
plt.show()

logger.info("Label distribution visualization complete")
# Out:
# 2025-11-17 01:38:21,535 - INFO - Label distribution visualization complete

# %% [markdown]
# ## 6. Label Formation Analysis

# %%
def analyze_label_formations(df: pd.DataFrame, top_n: int = 10) -> Dict:
    """Analyze the formation/patterns of each label."""
    formations = {}
    
    for label in df['label'].unique():
        label_df = df[df['label'] == label]
        text_counts = label_df['text'].value_counts()
        
        formations[label] = {
            'total_count': len(label_df),
            'unique_values': len(text_counts),
            'top_values': text_counts.head(top_n).to_dict(),
            'avg_length': label_df['length'].mean(),
            'median_length': label_df['length'].median(),
            'min_length': label_df['length'].min(),
            'max_length': label_df['length'].max()
        }
    
    return formations

formations = analyze_label_formations(df_annotations)

# Display formations for each label
for label, stats in formations.items():
    logger.info(f"\n{'='*60}")
    logger.info(f"Label: {label}")
    logger.info(f"Total occurrences: {stats['total_count']}")
    logger.info(f"Unique values: {stats['unique_values']}")
    logger.info(f"Length stats: avg={stats['avg_length']:.1f}, median={stats['median_length']}, min={stats['min_length']}, max={stats['max_length']}")
    logger.info(f"\nTop {len(stats['top_values'])} most common values:")
    for text, count in stats['top_values'].items():
        logger.info(f"  '{text[:50]}...': {count}")
# Out:
# 2025-11-17 01:38:28,095 - INFO -
# ============================================================
# 2025-11-17 01:38:28,096 - INFO - Label: LICENSE
# 2025-11-17 01:38:28,096 - INFO - Total occurrences: 211
# 2025-11-17 01:38:28,097 - INFO - Unique values: 109
# 2025-11-17 01:38:28,097 - INFO - Length stats: avg=19.7, median=17.0, min=3, max=89
# 2025-11-17 01:38:28,098 - INFO -
# Top 10 most common values:
# 2025-11-17 01:38:28,098 - INFO -   'GNU General Public License...': 20
# 2025-11-17 01:38:28,099 - INFO -   'Apache License, Version 2.0...': 13
# 2025-11-17 01:38:28,099 - INFO -   'MIT license...': 11
# 2025-11-17 01:38:28,100 - INFO -   'MIT...': 10
# 2025-11-17 01:38:28,100 - INFO -   'MIT License...': 9
# 2025-11-17 01:38:28,100 - INFO -   'Apache...': 7
# 2025-11-17 01:38:28,101 - INFO -   'CC-BY-4.0...': 5
# 2025-11-17 01:38:28,101 - INFO -   'Apache License 2.0...': 5
# 2025-11-17 01:38:28,101 - INFO -   'BSD 3-Clause...': 5
# 2025-11-17 01:38:28,101 - INFO -   'GNU Affero General Public License...': 5
# 2025-11-17 01:38:28,102 - INFO -
# ============================================================
# 2025-11-17 01:38:28,102 - INFO - Label: SOFTWARE_REQUIREMENTS
# 2025-11-17 01:38:28,102 - INFO - Total occurrences: 789
# 2025-11-17 01:38:28,103 - INFO - Unique values: 482
# 2025-11-17 01:38:28,103 - INFO - Length stats: avg=7.8, median=6.0, min=1, max=40
# 2025-11-17 01:38:28,103 - INFO -
# Top 10 most common values:
# 2025-11-17 01:38:28,104 - INFO -   'pip...': 43
# 2025-11-17 01:38:28,104 - INFO -   'Docker...': 16
# 2025-11-17 01:38:28,104 - INFO -   'setuptools...': 14
# 2025-11-17 01:38:28,105 - INFO -   'conda...': 12
# 2025-11-17 01:38:28,106 - INFO -   'cmake...': 11
# 2025-11-17 01:38:28,106 - INFO -   'CMake...': 9
# 2025-11-17 01:38:28,106 - INFO -   'numpy...': 9
# 2025-11-17 01:38:28,107 - INFO -   'pandas...': 8
# 2025-11-17 01:38:28,107 - INFO -   'tox...': 7
# 2025-11-17 01:38:28,107 - INFO -   'matplotlib...': 7
# 2025-11-17 01:38:28,107 - INFO -
# ============================================================
# 2025-11-17 01:38:28,108 - INFO - Label: RUNTIME_PLATFORM
# 2025-11-17 01:38:28,108 - INFO - Total occurrences: 102
# 2025-11-17 01:38:28,109 - INFO - Unique values: 78
# 2025-11-17 01:38:28,109 - INFO - Length stats: avg=14.6, median=12.0, min=6, max=51
# 2025-11-17 01:38:28,110 - INFO -
# Top 10 most common values:
# 2025-11-17 01:38:28,110 - INFO -   'Python 3...': 11
# 2025-11-17 01:38:28,110 - INFO -   'Node.js...': 6
# 2025-11-17 01:38:28,111 - INFO -   'NodeJs...': 3
# 2025-11-17 01:38:28,112 - INFO -   'Java 11...': 3
# 2025-11-17 01:38:28,112 - INFO -   'Python 3.9...': 2
# 2025-11-17 01:38:28,112 - INFO -   'python=3.12...': 2
# 2025-11-17 01:38:28,112 - INFO -   'Python 2.7...': 2
# 2025-11-17 01:38:28,113 - INFO -   'Python 3.9.12+...': 2
# 2025-11-17 01:38:28,113 - INFO -   'node.js...': 2
# 2025-11-17 01:38:28,113 - INFO -   'Python 3.8.x or 3.9.x...': 1
# 2025-11-17 01:38:28,113 - INFO -
# ============================================================
# 2025-11-17 01:38:28,114 - INFO - Label: SOFTWARE_REQUIREMENTS_VERSION
# 2025-11-17 01:38:28,114 - INFO - Total occurrences: 112
# 2025-11-17 01:38:28,114 - INFO - Unique values: 103
# 2025-11-17 01:38:28,114 - INFO - Length stats: avg=7.2, median=6.0, min=1, max=18
# 2025-11-17 01:38:28,115 - INFO -
# Top 10 most common values:
# 2025-11-17 01:38:28,115 - INFO -   '1.8...': 3
# 2025-11-17 01:38:28,115 - INFO -   '>= 0.18...': 2
# 2025-11-17 01:38:28,115 - INFO -   '3.16+...': 2
# 2025-11-17 01:38:28,115 - INFO -   '7+...': 2
# 2025-11-17 01:38:28,116 - INFO -   '>= 2.0.1...': 2
# 2025-11-17 01:38:28,116 - INFO -   '21...': 2
# 2025-11-17 01:38:28,116 - INFO -   '22.7+...': 2
# 2025-11-17 01:38:28,116 - INFO -   '11.0+...': 2
# 2025-11-17 01:38:28,117 - INFO -   '2.0.3...': 1
# 2025-11-17 01:38:28,117 - INFO -   '4.5+...': 1
# 2025-11-17 01:38:28,117 - INFO -
# ============================================================
# 2025-11-17 01:38:28,117 - INFO - Label: SOFTWARE_REQUIREMENTS_URL
# 2025-11-17 01:38:28,118 - INFO - Total occurrences: 274
# 2025-11-17 01:38:28,118 - INFO - Unique values: 237
# 2025-11-17 01:38:28,118 - INFO - Length stats: avg=34.0, median=32.0, min=15, max=92
# 2025-11-17 01:38:28,119 - INFO -
# Top 10 most common values:
# 2025-11-17 01:38:28,119 - INFO -   'https://pycqa.github.io/isort/...': 6
# 2025-11-17 01:38:28,119 - INFO -   'https://pypi.org/project/prospector/...': 6
# 2025-11-17 01:38:28,119 - INFO -   'https://docs.astral.sh/ruff/...': 3
# 2025-11-17 01:38:28,120 - INFO -   'https://github.com/conda-forge/miniforge...': 3
# 2025-11-17 01:38:28,120 - INFO -   'https://docs.docker.com/get-docker/...': 3
# 2025-11-17 01:38:28,120 - INFO -   'https://www.anaconda.com/download...': 3
# 2025-11-17 01:38:28,121 - INFO -   'https://pypi.org/...': 2
# 2025-11-17 01:38:28,121 - INFO -   'https://www.npmjs.com/package/cypress...': 2
# 2025-11-17 01:38:28,121 - INFO -   'https://www.google.com/chrome/...': 2
# 2025-11-17 01:38:28,122 - INFO -   'https://github.com/google/googletest...': 2
# 2025-11-17 01:38:28,122 - INFO -
# ============================================================
# 2025-11-17 01:38:28,123 - INFO - Label: REFERENCE_PUBLICATION_URL
# 2025-11-17 01:38:28,123 - INFO - Total occurrences: 75
# 2025-11-17 01:38:28,123 - INFO - Unique values: 68
# 2025-11-17 01:38:28,123 - INFO - Length stats: avg=52.9, median=43.0, min=30, max=175
# 2025-11-17 01:38:28,124 - INFO -
# Top 10 most common values:
# 2025-11-17 01:38:28,124 - INFO -   'http://www.tandfonline.com/doi/abs/10.1080/0094965...': 3
# 2025-11-17 01:38:28,124 - INFO -   'https://doi.org/10.1145/3641513.3650180...': 2
# 2025-11-17 01:38:28,124 - INFO -   'https://ieeexplore.ieee.org/abstract/document/1013...': 2
# 2025-11-17 01:38:28,125 - INFO -   'https://arxiv.org/pdf/2308.08187...': 2
# 2025-11-17 01:38:28,125 - INFO -   'https://academic.oup.com/bioinformatics/advance-ar...': 2
# 2025-11-17 01:38:28,125 - INFO -   'https://arxiv.org/abs/2307.01406...': 2
# 2025-11-17 01:38:28,125 - INFO -   'https://journals.aps.org/pra/abstract/10.1103/Phys...': 1
# 2025-11-17 01:38:28,125 - INFO -   'http://doi.org/10.4121/75ccbe86-76dd-4188-8c34-f6e...': 1
# 2025-11-17 01:38:28,126 - INFO -   'https://doi.org/10.5281/zenodo.13640303...': 1
# 2025-11-17 01:38:28,126 - INFO -   'https://doi.org/10.5281/zenodo.12188104...': 1
# 2025-11-17 01:38:28,126 - INFO -
# ============================================================
# 2025-11-17 01:38:28,127 - INFO - Label: REFERENCE_PUBLICATION
# 2025-11-17 01:38:28,127 - INFO - Total occurrences: 133
# 2025-11-17 01:38:28,128 - INFO - Unique values: 132
# 2025-11-17 01:38:28,128 - INFO - Length stats: avg=238.1, median=235.0, min=38, max=732
# 2025-11-17 01:38:28,128 - INFO -
# Top 10 most common values:
# 2025-11-17 01:38:28,129 - INFO -   'Tripathy, P., Rao, P., Balakrishnan, K., & Malladi...': 2
# 2025-11-17 01:38:28,129 - INFO -   'Marie Oestreich, Lisa Holsten, Shobhit Agrawal, Ki...': 1
# 2025-11-17 01:38:28,129 - INFO -   'Sidorenko, D., Goessling, H. F., Koldunov, N. V., ...': 1
# 2025-11-17 01:38:28,130 - INFO -   'G.P. Smith, D.M. Golden, M. Frenklach, N.W. Moriar...': 1
# 2025-11-17 01:38:28,130 - INFO -   'Danilov, S., Sidorenko, D., Wang, Q., and Jung, T....': 1
# 2025-11-17 01:38:28,130 - INFO -   'Danilov, S., Q. Wang, R. Timmermann, N. Iakovlev, ...': 1
# 2025-11-17 01:38:28,131 - INFO -   'Scholz, P., Sidorenko, D., Gurses, O., Danilov, S....': 1
# 2025-11-17 01:38:28,132 - INFO -   'Koldunov, N. V., Aizinger, V., Rakowsky, N., Schol...': 1
# 2025-11-17 01:38:28,132 - INFO -   'Zampieri, Lorenzo, Frank Kauker, Jörg Fröhle, Hiro...': 1
# 2025-11-17 01:38:28,132 - INFO -   'David G. Goodwin, Harry K. Moffat, Ingmar Schoegl,...': 1
# 2025-11-17 01:38:28,133 - INFO -
# ============================================================
# 2025-11-17 01:38:28,133 - INFO - Label: OPERATING_SYSTEM
# 2025-11-17 01:38:28,133 - INFO - Total occurrences: 249
# 2025-11-17 01:38:28,134 - INFO - Unique values: 34
# 2025-11-17 01:38:28,134 - INFO - Length stats: avg=5.7, median=5.0, min=3, max=20
# 2025-11-17 01:38:28,134 - INFO -
# Top 10 most common values:
# 2025-11-17 01:38:28,135 - INFO -   'Linux...': 71
# 2025-11-17 01:38:28,135 - INFO -   'Windows...': 56
# 2025-11-17 01:38:28,135 - INFO -   'Ubuntu...': 19
# 2025-11-17 01:38:28,136 - INFO -   'MacOS...': 18
# 2025-11-17 01:38:28,136 - INFO -   'macOS...': 17
# 2025-11-17 01:38:28,136 - INFO -   'Mac...': 10
# 2025-11-17 01:38:28,137 - INFO -   'Debian...': 9
# 2025-11-17 01:38:28,137 - INFO -   'Unix...': 6
# 2025-11-17 01:38:28,137 - INFO -   'OSX...': 6
# 2025-11-17 01:38:28,138 - INFO -   'MacOSX...': 5
# 2025-11-17 01:38:28,138 - INFO -
# ============================================================
# 2025-11-17 01:38:28,139 - INFO - Label: DOCUMENTATION_URL
# 2025-11-17 01:38:28,139 - INFO - Total occurrences: 230
# 2025-11-17 01:38:28,139 - INFO - Unique values: 209
# 2025-11-17 01:38:28,139 - INFO - Length stats: avg=44.5, median=43.0, min=18, max=118
# 2025-11-17 01:38:28,140 - INFO -
# Top 10 most common values:
# 2025-11-17 01:38:28,140 - INFO -   'https://amuse.readthedocs.io...': 3
# 2025-11-17 01:38:28,140 - INFO -   'https://mycoai.github.io/taxotagger...': 3
# 2025-11-17 01:38:28,141 - INFO -   'https://indigo-dc.gitbooks.io/token-translation-se...': 2
# 2025-11-17 01:38:28,141 - INFO -   'https://annubs.github.io/annubes/latest/...': 2
# 2025-11-17 01:38:28,141 - INFO -   'https://basicpy.readthedocs.io/en/latest/...': 2
# 2025-11-17 01:38:28,143 - INFO -   'https://jhidding.github.io/GraphvizDotLang.jl...': 2
# 2025-11-17 01:38:28,191 - INFO -   'http://deeptools.readthedocs.org/...': 2
# 2025-11-17 01:38:28,193 - INFO -   'https://docs.vantage6.ai...': 2
# 2025-11-17 01:38:28,194 - INFO -   'https://datasail.readthedocs.io/en/latest/index.ht...': 2
# 2025-11-17 01:38:28,194 - INFO -   'https://cat.readthedocs.io/en/latest/...': 2
# 2025-11-17 01:38:28,201 - INFO -
# ============================================================
# 2025-11-17 01:38:28,207 - INFO - Label: CITATION
# 2025-11-17 01:38:28,212 - INFO - Total occurrences: 159
# 2025-11-17 01:38:28,213 - INFO - Unique values: 158
# 2025-11-17 01:38:28,213 - INFO - Length stats: avg=246.7, median=239.0, min=43, max=628
# 2025-11-17 01:38:28,214 - INFO -
# Top 10 most common values:
# 2025-11-17 01:38:28,214 - INFO -   'J. M. Hoekstra and J. Ellerbroek, "[BlueSky ATC Si...': 2
# 2025-11-17 01:38:28,214 - INFO -   '[Jünger, Jakob] https://www.uni-muenster.de/Kowi/p...': 1
# 2025-11-17 01:38:28,215 - INFO -   'Gutiérrez Hermosillo Muriedas, J.P., Flügel, K., D...': 1
# 2025-11-17 01:38:28,215 - INFO -   'Piter A, Haghshenas Haghighi M, FERN.Lab, Motagh M...': 1
# 2025-11-17 01:38:28,215 - INFO -   'Boykov Y, Kolmogorov V (2004). An experimental com...': 1
# 2025-11-17 01:38:28,216 - INFO -   'Cheng et al., (2024). GrainLearning: A Bayesian un...': 1
# 2025-11-17 01:38:28,216 - INFO -   'H. Cheng, T. Shuku, K. Thoeni, P. Tempone, S. Ludi...': 1
# 2025-11-17 01:38:28,216 - INFO -   'McElroy, Wood, Bond, Mulvenna, Shevlin, Ploubidis,...': 1
# 2025-11-17 01:38:28,216 - INFO -   'Timothy C. Lethbridge, Andrew Forward, Omar Badred...': 1
# 2025-11-17 01:38:28,216 - INFO -   'University of Ottawa, Umple, https://umple.org/rel...': 1
# 2025-11-17 01:38:28,217 - INFO -
# ============================================================
# 2025-11-17 01:38:28,217 - INFO - Label: CITATION_URL
# 2025-11-17 01:38:28,217 - INFO - Total occurrences: 240
# 2025-11-17 01:38:28,217 - INFO - Unique values: 223
# 2025-11-17 01:38:28,218 - INFO - Length stats: avg=41.6, median=39.0, min=21, max=150
# 2025-11-17 01:38:28,218 - INFO -
# Top 10 most common values:
# 2025-11-17 01:38:28,218 - INFO -   'https://doi.org/10.5281/zenodo.7568610...': 3
# 2025-11-17 01:38:28,218 - INFO -   'https://zenodo.org/badge/latestdoi/26165004...': 2
# 2025-11-17 01:38:28,218 - INFO -   'https://doi.org/10.5281/zenodo.7123965...': 2
# 2025-11-17 01:38:28,219 - INFO -   'https://doi.org/10.5281/zenodo.3484711...': 2
# 2025-11-17 01:38:28,219 - INFO -   'https://zenodo.org/badge/latestdoi/472769298...': 2
# 2025-11-17 01:38:28,219 - INFO -   'https://doi.org/10.5281/zenodo.7034838...': 2
# 2025-11-17 01:38:28,220 - INFO -   'https://zenodo.org/badge/latestdoi/29671667...': 2
# 2025-11-17 01:38:28,220 - INFO -   'https://doi.org/10.5281/zenodo.7615693...': 2
# 2025-11-17 01:38:28,220 - INFO -   'https://doi.org/10.21105/joss.06434...': 2
# 2025-11-17 01:38:28,220 - INFO -   'https://zenodo.org/records/13643609...': 2
# 2025-11-17 01:38:28,220 - INFO -
# ============================================================
# 2025-11-17 01:38:28,221 - INFO - Label: RELATED_LINK
# 2025-11-17 01:38:28,221 - INFO - Total occurrences: 50
# 2025-11-17 01:38:28,221 - INFO - Unique values: 49
# 2025-11-17 01:38:28,222 - INFO - Length stats: avg=24.7, median=21.5, min=16, max=66
# 2025-11-17 01:38:28,222 - INFO -
# Top 10 most common values:
# 2025-11-17 01:38:28,223 - INFO -   'https://www.limesurvey.org...': 2
# 2025-11-17 01:38:28,224 - INFO -   'https://cwrc-writer.cwrc.ca/...': 1
# 2025-11-17 01:38:28,225 - INFO -   'https://icos-cp.eu...': 1
# 2025-11-17 01:38:28,225 - INFO -   'https://harmonydata.ac.uk/app/...': 1
# 2025-11-17 01:38:28,238 - INFO -   'https://harmonydata.ac.uk/...': 1
# 2025-11-17 01:38:28,239 - INFO -   'https://umple.org/...': 1
# 2025-11-17 01:38:28,240 - INFO -   'https://try.umple.org...': 1
# 2025-11-17 01:38:28,240 - INFO -   'https://www.umple.org...': 1
# 2025-11-17 01:38:28,240 - INFO -   'https://sumo.dlr.de/...': 1
# 2025-11-17 01:38:28,240 - INFO -   'https://research-software-directory.org...': 1
# 2025-11-17 01:38:28,241 - INFO -
# ============================================================
# 2025-11-17 01:38:28,241 - INFO - Label: BUILD_INSTRUCTIONS
# 2025-11-17 01:38:28,241 - INFO - Total occurrences: 69
# 2025-11-17 01:38:28,241 - INFO - Unique values: 65
# 2025-11-17 01:38:28,242 - INFO - Length stats: avg=56.6, median=57.0, min=18, max=106
# 2025-11-17 01:38:28,242 - INFO -
# Top 10 most common values:
# 2025-11-17 01:38:28,242 - INFO -   'https://spack.readthedocs.io/en/latest/package_lis...': 3
# 2025-11-17 01:38:28,243 - INFO -   'http://www.jemris.org...': 2
# 2025-11-17 01:38:28,243 - INFO -   'https://github.com/TUDelft-CNS-ATM/bluesky/wiki...': 2
# 2025-11-17 01:38:28,243 - INFO -   'https://luhipi.github.io/sarvey/main...': 1
# 2025-11-17 01:38:28,243 - INFO -   'https://rbuehler.github.io/vasca/...': 1
# 2025-11-17 01:38:28,244 - INFO -   'https://cwltool.readthedocs.io/en/latest/?badge=la...': 1
# 2025-11-17 01:38:28,244 - INFO -   'https://sumo.dlr.de/docs/Developer/Main.html#build...': 1
# 2025-11-17 01:38:28,244 - INFO -   'https://www.youtube.com/watch?v=enWh0-4I0Sg...': 1
# 2025-11-17 01:38:28,244 - INFO -   'https://inseq.readthedocs.io...': 1
# 2025-11-17 01:38:28,244 - INFO -   'https://orangedatamining.com/download...': 1
# 2025-11-17 01:38:28,245 - INFO -
# ============================================================
# 2025-11-17 01:38:28,245 - INFO - Label: CONTINUOUS_INTEGRATION
# 2025-11-17 01:38:28,245 - INFO - Total occurrences: 38
# 2025-11-17 01:38:28,245 - INFO - Unique values: 38
# 2025-11-17 01:38:28,246 - INFO - Length stats: avg=57.0, median=57.5, min=33, max=92
# 2025-11-17 01:38:28,246 - INFO -
# Top 10 most common values:
# 2025-11-17 01:38:28,247 - INFO -   'https://travis-ci.org/openPSTD/openPSTD...': 1
# 2025-11-17 01:38:28,247 - INFO -   'https://travis-ci.org/candYgene/QTM...': 1
# 2025-11-17 01:38:28,248 - INFO -   'https://travis-ci.org/nlesc-ave/ave-rest-service...': 1
# 2025-11-17 01:38:28,248 - INFO -   'https://github.com/rbuehler/vasca/actions/workflow...': 1
# 2025-11-17 01:38:28,248 - INFO -   'https://travis-ci.org/obiba/agate...': 1
# 2025-11-17 01:38:28,249 - INFO -   'https://github.com/teamtomo/membrain-seg/actions/w...': 1
# 2025-11-17 01:38:28,249 - INFO -   'https://github.com/OpenDA-Association/OpenDA/actio...': 1
# 2025-11-17 01:38:28,249 - INFO -   'https://travis-ci.org/recipy/recipy...': 1
# 2025-11-17 01:38:28,249 - INFO -   'https://travis-ci.org/modAL-python/modAL...': 1
# 2025-11-17 01:38:28,250 - INFO -   'https://github.com/medicalinformatics/mainzelliste...': 1
# 2025-11-17 01:38:28,250 - INFO -
# ============================================================
# 2025-11-17 01:38:28,251 - INFO - Label: LICENSE_URL
# 2025-11-17 01:38:28,251 - INFO - Total occurrences: 138
# 2025-11-17 01:38:28,251 - INFO - Unique values: 102
# 2025-11-17 01:38:28,252 - INFO - Length stats: avg=49.5, median=49.0, min=25, max=82
# 2025-11-17 01:38:28,252 - INFO -
# Top 10 most common values:
# 2025-11-17 01:38:28,252 - INFO -   'https://opensource.org/licenses/MIT...': 11
# 2025-11-17 01:38:28,252 - INFO -   'http://www.apache.org/licenses/LICENSE-2.0...': 8
# 2025-11-17 01:38:28,253 - INFO -   'https://opensource.org/licenses/Apache-2.0...': 4
# 2025-11-17 01:38:28,253 - INFO -   'https://www.gnu.org/licenses/gpl-3.0...': 4
# 2025-11-17 01:38:28,253 - INFO -   'https://opensource.org/licenses/BSD-3-Clause...': 3
# 2025-11-17 01:38:28,253 - INFO -   'https://creativecommons.org/licenses/by/4.0/...': 3
# 2025-11-17 01:38:28,254 - INFO -   'https://github.com/ChASE-library/ChASE/blob/master...': 2
# 2025-11-17 01:38:28,254 - INFO -   'https://github.com/astral-sh/ruff/blob/main/LICENS...': 2
# 2025-11-17 01:38:28,254 - INFO -   'https://www.gnu.org/licenses/lgpl-3.0.html...': 2
# 2025-11-17 01:38:28,254 - INFO -   'https://www.gnu.org/licenses/old-licenses/gpl-2.0....': 2
# 2025-11-17 01:38:28,255 - INFO -
# ============================================================
# 2025-11-17 01:38:28,255 - INFO - Label: CITATION_BIBTEX
# 2025-11-17 01:38:28,255 - INFO - Total occurrences: 62
# 2025-11-17 01:38:28,256 - INFO - Unique values: 62
# 2025-11-17 01:38:28,256 - INFO - Length stats: avg=415.4, median=354.5, min=135, max=1829
# 2025-11-17 01:38:28,257 - INFO -
# Top 10 most common values:
# 2025-11-17 01:38:28,257 - INFO -   '@inproceedings{heat2020, title={{HeAT -- a Distrib...': 1
# 2025-11-17 01:38:28,258 - INFO -   '@article{keller2024vitessce, title = {{Vitessce: i...': 1
# 2025-11-17 01:38:28,258 - INFO -   '@INPROCEEDINGS{10889702, author={de Groot, D. and ...': 1
# 2025-11-17 01:38:28,258 - INFO -   '@inproceedings{He-IUI-2025, title={Is Conversation...': 1
# 2025-11-17 01:38:28,259 - INFO -   '@article{Corbino2024, doi = {10.21105/joss.06288},...': 1
# 2025-11-17 01:38:28,259 - INFO -   '@misc{MOLE_user_manual, author = {Barra, Valeria a...': 1
# 2025-11-17 01:38:28,259 - INFO -   '@misc{ROBIST, doi = {10.5281/zenodo.10143595}, yea...': 1
# 2025-11-17 01:38:28,259 - INFO -   '@InProceedings{10.1007/978-3-031-39698-4_2, author...': 1
# 2025-11-17 01:38:28,260 - INFO -   '@inproceedings{sarti-etal-2023-inseq, title = "Ins...': 1
# 2025-11-17 01:38:28,260 - INFO -   '@article{mcelroy2024using, title={Using natural la...': 1
# 2025-11-17 01:38:28,260 - INFO -
# ============================================================
# 2025-11-17 01:38:28,260 - INFO - Label: REFERENCE_PUBLICATION_BIBTEX
# 2025-11-17 01:38:28,261 - INFO - Total occurrences: 4
# 2025-11-17 01:38:28,261 - INFO - Unique values: 4
# 2025-11-17 01:38:28,261 - INFO - Length stats: avg=418.0, median=449.5, min=302, max=471
# 2025-11-17 01:38:28,262 - INFO -
# Top 4 most common values:
# 2025-11-17 01:38:28,262 - INFO -   '@inproceedings{bilgin2018utilizing, title={Utilizi...': 1
# 2025-11-17 01:38:28,263 - INFO -   '@inproceedings{smeenk2019dh, author = "Kim Smeenk ...': 1
# 2025-11-17 01:38:28,263 - INFO -   '@inproceedings{klaver2019ictopen, author = "Tom Kl...': 1
# 2025-11-17 01:38:28,264 - INFO -   '@inproceedings{zhang2019raven, title={RAVEN: A Dat...': 1

# %%
# Create detailed formation report for each label
def create_formation_report(label: str, df: pd.DataFrame) -> pd.DataFrame:
    """Create a detailed formation report for a specific label."""

    label_df = df[df['label'] == label]
    formation_counts = label_df['text'].value_counts().reset_index()
    formation_counts.columns = ['text', 'count']
    formation_counts['percentage'] = (formation_counts['count'] / len(label_df) * 100).round(2)
    return formation_counts

# Example: Show formation report for LICENSE label
if 'LICENSE' in df_annotations['label'].values:
    license_report = create_formation_report('LICENSE', df_annotations)
    print("\nLICENSE Formation Report:")
    print(license_report.head(50))
# Out:
# LICENSE Formation Report:
#                                                  text  count  percentage
# 0                          GNU General Public License     20        9.48
# 1                         Apache License, Version 2.0     13        6.16
# 2                                         MIT license     11        5.21
# 3                                                 MIT     10        4.74
# 4                                         MIT License      9        4.27
# 5                                              Apache      7        3.32
# 6                                           CC-BY-4.0      5        2.37
# 7                                  Apache License 2.0      5        2.37
# 8                                        BSD 3-Clause      5        2.37
# 9                   GNU Affero General Public License      5        2.37
# 10                               BSD 3-Clause License      4        1.90
# 11                                         Apache 2.0      4        1.90
# 12                    GNU General Public License v3.0      3        1.42
# 13                                            CC0-1.0      3        1.42
# 14                                         Apache-2.0      3        1.42
# 15                                 GPLv2 or any later      2        0.95
# 16                                             GPLv3+      2        0.95
# 17                               3-clause BSD license      2        0.95
# 18     Creative Commons Attribution 4.0 International      2        0.95
# 19                      GNU General Public License v3      2        0.95
# 20                                    CC BY-NC-SA 4.0      2        0.95
# 21                  GNU Lesser General Public License      2        0.95
# 22                                 Apache 2.0 license      2        0.95
# 23                                                BSD      2        0.95
# 24                                 Apache 2.0 License      2        0.95
# 25                   Eclipse Public License Version 2      1        0.47
# 26                                    MIT OSS licence      1        0.47
# 27                                       GPL3 licence      1        0.47
# 28             GNU General Public License v2 or later      1        0.47
# 29                                  CC BY 4.0 license      1        0.47
# 30            Jisk Attema Apache Software License 2.0      1        0.47
# 31                      GNU General Public License v2      1        0.47
# 32              GNU General Public License, version 3      1        0.47
# 33                                           AGPLv3.0      1        0.47
# 34                           BSD-style custom license      1        0.47
# 35               GNU General Public License Version 3      1        0.47
# 36                                            LGPLv3+      1        0.47
# 37                                       BSD 2-Clause      1        0.47
# 38                                              GPLv3      1        0.47
# 39                                          CC BY-4.0      1        0.47
# 40                               BSD-3-Clause license      1        0.47
# 41  Creative Commons Attribution 4.0 International...      1        0.47
# 42  Creative Commons Attribution-NoDerivatives 4.0...      1        0.47
# 43                                     Apache license      1        0.47
# 44                                   LGPL-3.0 License      1        0.47
# 45                                Apache License v2.0      1        0.47
# 46                                          CC-BY 4.0      1        0.47
# 47                                            LGPL v2      1        0.47
# 48  Creative Commons Attribution-Share-Alike 3.0 L...      1        0.47
# 49                     GNU Free Documentation License      1        0.47

# %% [markdown]
# ## 7. Dataset Balance Analysis

# %%
def analyze_dataset_balance(df: pd.DataFrame) -> Dict:
    """Analyze dataset balance and identify potential overfitting risks."""
    label_counts = df['label'].value_counts()
    
    # Calculate imbalance metrics
    max_count = label_counts.max()
    min_count = label_counts.min()
    imbalance_ratio = max_count / min_count if min_count > 0 else float('inf')
    
    # Calculate coefficient of variation
    cv = (label_counts.std() / label_counts.mean()) * 100
    
    balance_info = {
        'max_count': max_count,
        'min_count': min_count,
        'imbalance_ratio': imbalance_ratio,
        'coefficient_of_variation': cv,
        'mean_count': label_counts.mean(),
        'median_count': label_counts.median()
    }
    
    logger.info("\n" + "="*60)
    logger.info("DATASET BALANCE ANALYSIS")
    logger.info("="*60)
    logger.info(f"Maximum label count: {max_count}")
    logger.info(f"Minimum label count: {min_count}")
    logger.info(f"Imbalance ratio: {imbalance_ratio:.2f}")
    logger.info(f"Coefficient of variation: {cv:.2f}%")
    logger.info(f"Mean count per label: {balance_info['mean_count']:.2f}")
    logger.info(f"Median count per label: {balance_info['median_count']:.2f}")
    
    # Provide recommendations
    if imbalance_ratio > 10:
        logger.warning("⚠️  HIGH IMBALANCE DETECTED! Imbalance ratio > 10")
        logger.warning("   Consider data augmentation or resampling techniques")
    elif imbalance_ratio > 5:
        logger.warning("⚠️  MODERATE IMBALANCE DETECTED! Imbalance ratio > 5")
        logger.warning("   Monitor model performance on minority classes")
    else:
        logger.info("✓ Dataset is relatively balanced")
    
    return balance_info

balance_info = analyze_dataset_balance(df_annotations)
# Out:
# 2025-11-17 01:38:49,606 - INFO -
# ============================================================
# 2025-11-17 01:38:49,607 - INFO - DATASET BALANCE ANALYSIS
# 2025-11-17 01:38:49,607 - INFO - ============================================================
# 2025-11-17 01:38:49,607 - INFO - Maximum label count: 789
# 2025-11-17 01:38:49,608 - INFO - Minimum label count: 4
# 2025-11-17 01:38:49,608 - INFO - Imbalance ratio: 197.25
# 2025-11-17 01:38:49,609 - INFO - Coefficient of variation: 103.52%
# 2025-11-17 01:38:49,609 - INFO - Mean count per label: 172.65
# 2025-11-17 01:38:49,610 - INFO - Median count per label: 133.00
# 2025-11-17 01:38:49,610 - WARNING - ⚠️  HIGH IMBALANCE DETECTED! Imbalance ratio > 10
# 2025-11-17 01:38:49,611 - WARNING -    Consider data augmentation or resampling techniques

# %% [markdown]
# ## 8. Overfitting Risk Analysis

# %%
def analyze_overfitting_risk(df: pd.DataFrame) -> pd.DataFrame:
    """Identify potential overfitting risks based on repetition patterns."""
    overfitting_risks = []
    
    for label in df['label'].unique():
        label_df = df[df['label'] == label]
        text_counts = label_df['text'].value_counts()
        
        # Calculate diversity metrics
        total_count = len(label_df)
        unique_count = len(text_counts)
        diversity_ratio = unique_count / total_count if total_count > 0 else 0
        
        # Find highly repeated values
        high_repetition = text_counts[text_counts > (total_count * 0.1)]  # >10% repetition
        
        risk_level = 'LOW'
        if diversity_ratio < 0.3:
            risk_level = 'HIGH'
        elif diversity_ratio < 0.6:
            risk_level = 'MEDIUM'
        
        overfitting_risks.append({
            'label': label,
            'total_count': total_count,
            'unique_count': unique_count,
            'diversity_ratio': diversity_ratio,
            'high_repetition_count': len(high_repetition),
            'risk_level': risk_level
        })
    
    risk_df = pd.DataFrame(overfitting_risks).sort_values('diversity_ratio')
    
    logger.info("\n" + "="*60)
    logger.info("OVERFITTING RISK ANALYSIS")
    logger.info("="*60)
    
    for _, row in risk_df.iterrows():
        logger.info(f"\nLabel: {row['label']}")
        logger.info(f"  Diversity ratio: {row['diversity_ratio']:.2%}")
        logger.info(f"  Risk level: {row['risk_level']}")
        logger.info(f"  Highly repeated values: {row['high_repetition_count']}")
    
    return risk_df

risk_analysis = analyze_overfitting_risk(df_annotations)
risk_analysis
# Out:
# 2025-11-16 08:14:41,194 - INFO -
# ============================================================
# 2025-11-16 08:14:41,195 - INFO - OVERFITTING RISK ANALYSIS
# 2025-11-16 08:14:41,195 - INFO - ============================================================
# 2025-11-16 08:14:41,195 - INFO -
# Label: OPERATING_SYSTEM
# 2025-11-16 08:14:41,196 - INFO -   Diversity ratio: 13.65%
# 2025-11-16 08:14:41,196 - INFO -   Risk level: HIGH
# 2025-11-16 08:14:41,197 - INFO -   Highly repeated values: 2
# 2025-11-16 08:14:41,207 - INFO -
# Label: RUNTIME_PLATFORM
# 2025-11-16 08:14:41,208 - INFO -   Diversity ratio: 14.85%
# 2025-11-16 08:14:41,213 - INFO -   Risk level: HIGH
# 2025-11-16 08:14:41,218 - INFO -   Highly repeated values: 1
# 2025-11-16 08:14:41,223 - INFO -
# Label: LICENSE
# 2025-11-16 08:14:41,227 - INFO -   Diversity ratio: 51.20%
# 2025-11-16 08:14:41,230 - INFO -   Risk level: MEDIUM
# 2025-11-16 08:14:41,231 - INFO -   Highly repeated values: 0
# 2025-11-16 08:14:41,233 - INFO -
# Label: RUNTIME_PLATFORM_VERSION
# 2025-11-16 08:14:41,234 - INFO -   Diversity ratio: 54.29%
# 2025-11-16 08:14:41,235 - INFO -   Risk level: MEDIUM
# 2025-11-16 08:14:41,235 - INFO -   Highly repeated values: 0
# 2025-11-16 08:14:41,235 - INFO -
# Label: SOFTWARE_REQUIREMENTS
# 2025-11-16 08:14:41,235 - INFO -   Diversity ratio: 61.20%
# 2025-11-16 08:14:41,235 - INFO -   Risk level: LOW
# 2025-11-16 08:14:41,236 - INFO -   Highly repeated values: 0
# 2025-11-16 08:14:41,236 - INFO -
# Label: LICENSE_URL
# 2025-11-16 08:14:41,237 - INFO -   Diversity ratio: 73.91%
# 2025-11-16 08:14:41,237 - INFO -   Risk level: LOW
# 2025-11-16 08:14:41,238 - INFO -   Highly repeated values: 0
# 2025-11-16 08:14:41,238 - INFO -
# Label: SOFTWARE_REQUIREMENTS_URL
# 2025-11-16 08:14:41,238 - INFO -   Diversity ratio: 85.93%
# 2025-11-16 08:14:41,238 - INFO -   Risk level: LOW
# 2025-11-16 08:14:41,239 - INFO -   Highly repeated values: 0
# 2025-11-16 08:14:41,239 - INFO -
# Label: REFERENCE_PUBLICATION_URL
# 2025-11-16 08:14:41,239 - INFO -   Diversity ratio: 90.67%
# 2025-11-16 08:14:41,240 - INFO -   Risk level: LOW
# 2025-11-16 08:14:41,240 - INFO -   Highly repeated values: 0
# 2025-11-16 08:14:41,240 - INFO -
# Label: DOCUMENTATION_URL
# 2025-11-16 08:14:41,241 - INFO -   Diversity ratio: 90.87%
# 2025-11-16 08:14:41,241 - INFO -   Risk level: LOW
# 2025-11-16 08:14:41,241 - INFO -   Highly repeated values: 0
# 2025-11-16 08:14:41,242 - INFO -
# Label: SOFTWARE_REQUIREMENTS_VERSION
# 2025-11-16 08:14:41,242 - INFO -   Diversity ratio: 92.31%
# 2025-11-16 08:14:41,242 - INFO -   Risk level: LOW
# 2025-11-16 08:14:41,242 - INFO -   Highly repeated values: 0
# 2025-11-16 08:14:41,243 - INFO -
# Label: CITATION_URL
# 2025-11-16 08:14:41,243 - INFO -   Diversity ratio: 92.92%
# 2025-11-16 08:14:41,244 - INFO -   Risk level: LOW
# 2025-11-16 08:14:41,245 - INFO -   Highly repeated values: 0
# 2025-11-16 08:14:41,246 - INFO -
# Label: BUILD_INSTRUCTIONS
# 2025-11-16 08:14:41,247 - INFO -   Diversity ratio: 94.44%
# 2025-11-16 08:14:41,248 - INFO -   Risk level: LOW
# 2025-11-16 08:14:41,253 - INFO -   Highly repeated values: 0
# 2025-11-16 08:14:41,254 - INFO -
# Label: RELATED_LINK
# 2025-11-16 08:14:41,254 - INFO -   Diversity ratio: 98.00%
# 2025-11-16 08:14:41,254 - INFO -   Risk level: LOW
# 2025-11-16 08:14:41,255 - INFO -   Highly repeated values: 0
# 2025-11-16 08:14:41,255 - INFO -
# Label: REFERENCE_PUBLICATION
# 2025-11-16 08:14:41,255 - INFO -   Diversity ratio: 99.25%
# 2025-11-16 08:14:41,255 - INFO -   Risk level: LOW
# 2025-11-16 08:14:41,256 - INFO -   Highly repeated values: 0
# 2025-11-16 08:14:41,256 - INFO -
# Label: CITATION
# 2025-11-16 08:14:41,256 - INFO -   Diversity ratio: 99.38%
# 2025-11-16 08:14:41,257 - INFO -   Risk level: LOW
# 2025-11-16 08:14:41,257 - INFO -   Highly repeated values: 0
# 2025-11-16 08:14:41,257 - INFO -
# Label: CONTINUOUS_INTEGRATION
# 2025-11-16 08:14:41,258 - INFO -   Diversity ratio: 100.00%
# 2025-11-16 08:14:41,258 - INFO -   Risk level: LOW
# 2025-11-16 08:14:41,258 - INFO -   Highly repeated values: 0
# 2025-11-16 08:14:41,259 - INFO -
# Label: CITATION_BIBTEX
# 2025-11-16 08:14:41,259 - INFO -   Diversity ratio: 100.00%
# 2025-11-16 08:14:41,259 - INFO -   Risk level: LOW
# 2025-11-16 08:14:41,260 - INFO -   Highly repeated values: 0
# 2025-11-16 08:14:41,260 - INFO -
# Label: REFERENCE_PUBLICATION_BIBTEX
# 2025-11-16 08:14:41,260 - INFO -   Diversity ratio: 100.00%
# 2025-11-16 08:14:41,261 - INFO -   Risk level: LOW
# 2025-11-16 08:14:41,261 - INFO -   Highly repeated values: 4
#                             label  total_count  unique_count  diversity_ratio  \
# 9                OPERATING_SYSTEM          249            34         0.136546
# 12               RUNTIME_PLATFORM          101            15         0.148515
# 0                         LICENSE          209           107         0.511962
# 4        RUNTIME_PLATFORM_VERSION          105            57         0.542857
# 1           SOFTWARE_REQUIREMENTS          786           481         0.611959
# 15                    LICENSE_URL          138           102         0.739130
# 6       SOFTWARE_REQUIREMENTS_URL          270           232         0.859259
# 7       REFERENCE_PUBLICATION_URL           75            68         0.906667
# 10              DOCUMENTATION_URL          230           209         0.908696
# 5   SOFTWARE_REQUIREMENTS_VERSION          117           108         0.923077
# 11                   CITATION_URL          240           223         0.929167
# 2              BUILD_INSTRUCTIONS           72            68         0.944444
# 13                   RELATED_LINK           50            49         0.980000
# 8           REFERENCE_PUBLICATION          133           132         0.992481
# 3                        CITATION          162           161         0.993827
# 14         CONTINUOUS_INTEGRATION           38            38         1.000000
# 16                CITATION_BIBTEX           62            62         1.000000
# 17   REFERENCE_PUBLICATION_BIBTEX            4             4         1.000000
#
#     high_repetition_count risk_level
# 9                       2       HIGH
# 12                      1       HIGH
# 0                       0     MEDIUM
# 4                       0     MEDIUM
# 1                       0        LOW
# 15                      0        LOW
# 6                       0        LOW
# 7                       0        LOW
# 10                      0        LOW
# 5                       0        LOW
# 11                      0        LOW
# 2                       0        LOW
# 13                      0        LOW
# 8                       0        LOW
# 3                       0        LOW
# 14                      0        LOW
# 16                      0        LOW
# 17                      4        LOW

# %%
# Visualize overfitting risk
fig, ax = plt.subplots(figsize=(12, 6))

colors = {'HIGH': 'red', 'MEDIUM': 'orange', 'LOW': 'green'}
bar_colors = [colors[risk] for risk in risk_analysis['risk_level']]

ax.barh(risk_analysis['label'], risk_analysis['diversity_ratio'], color=bar_colors)
ax.set_xlabel('Diversity Ratio', fontsize=12)
ax.set_ylabel('Label', fontsize=12)
ax.set_title('Overfitting Risk by Label (Diversity Ratio)', fontsize=14, fontweight='bold')
ax.axvline(x=0.3, color='red', linestyle='--', label='High Risk Threshold')
ax.axvline(x=0.6, color='orange', linestyle='--', label='Medium Risk Threshold')
ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 9. Label Deletion Tool

# %%
def delete_label_from_dataset(dataset: List[Dict], label_to_delete: str) -> List[Dict]:
    """Remove all annotations of a specific label from the dataset."""
    deleted_count = 0
    
    for sample in dataset:
        for annotation in sample.get('annotations', []):
            original_count = len(annotation.get('result', []))
            
            # Filter out the label
            annotation['result'] = [
                result for result in annotation.get('result', [])
                if not (result.get('type') == 'labels' and 
                       label_to_delete in result.get('value', {}).get('labels', []))
            ]
            
            deleted_count += original_count - len(annotation['result'])
            annotation['result_count'] = len(annotation['result'])
    
    logger.info(f"Deleted {deleted_count} annotations with label '{label_to_delete}'")
    return dataset

def save_cleaned_dataset(dataset: List[Dict], output_path: Path):
    """Save the cleaned dataset to a file."""
    with open(output_path, 'w', encoding='utf-8') as f:
        json.dump(dataset, f, indent=2, ensure_ascii=False)
    logger.info(f"Saved cleaned dataset to {output_path}")

# Example usage (commented out to prevent accidental deletion)
#label_to_remove = 'REFERENCE_PUBLICATION_BIBTEX'
#cleaned_dataset = delete_label_from_dataset(dataset.copy(), label_to_remove)
#save_cleaned_dataset(cleaned_dataset, DATASET_PATH.parent / 'o_dataset.json')

# %% [markdown]
# ## 10. Summary Report

# %%
def generate_summary_report(df: pd.DataFrame, balance_info: Dict, risk_analysis: pd.DataFrame):
    """Generate a comprehensive summary report."""
    logger.info("\n" + "="*60)
    logger.info("DATASET SUMMARY REPORT")
    logger.info("="*60)
    
    logger.info(f"\nTotal annotations: {len(df)}")
    logger.info(f"Total unique labels: {df['label'].nunique()}")
    logger.info(f"Total samples: {df['sample_id'].nunique()}")
    
    logger.info(f"\nBalance Metrics:")
    logger.info(f"  Imbalance ratio: {balance_info['imbalance_ratio']:.2f}")
    logger.info(f"  Coefficient of variation: {balance_info['coefficient_of_variation']:.2f}%")
    
    high_risk_labels = risk_analysis[risk_analysis['risk_level'] == 'HIGH']
    logger.info(f"\nOverfitting Risk:")
    logger.info(f"  High risk labels: {len(high_risk_labels)}")
    if len(high_risk_labels) > 0:
        logger.info(f"  Labels: {', '.join(high_risk_labels['label'].tolist())}")
    
    logger.info("\nRecommendations:")
    if balance_info['imbalance_ratio'] > 5:
        logger.info("  - Consider data augmentation for minority classes")
        logger.info("  - Use class weights during training")
    if len(high_risk_labels) > 0:
        logger.info("  - Collect more diverse examples for high-risk labels")
        logger.info("  - Consider data augmentation techniques")
    
    logger.info("\n" + "="*60)

generate_summary_report(df_annotations, balance_info, risk_analysis)
# Out:
# 2025-11-17 01:39:01,680 - INFO -
# ============================================================
# 2025-11-17 01:39:01,681 - INFO - DATASET SUMMARY REPORT
# 2025-11-17 01:39:01,681 - INFO - ============================================================
# 2025-11-17 01:39:01,682 - INFO -
# Total annotations: 2935
# 2025-11-17 01:39:01,682 - INFO - Total unique labels: 17
# 2025-11-17 01:39:01,683 - INFO - Total samples: 798
# 2025-11-17 01:39:01,683 - INFO -
# Balance Metrics:
# 2025-11-17 01:39:01,684 - INFO -   Imbalance ratio: 197.25
# 2025-11-17 01:39:01,684 - INFO -   Coefficient of variation: 103.52%
# 2025-11-17 01:39:01,684 - INFO -
# Overfitting Risk:
# 2025-11-17 01:39:01,685 - INFO -   High risk labels: 2
# 2025-11-17 01:39:01,686 - INFO -   Labels: OPERATING_SYSTEM, RUNTIME_PLATFORM
# 2025-11-17 01:39:01,686 - INFO -
# Recommendations:
# 2025-11-17 01:39:01,687 - INFO -   - Consider data augmentation for minority classes
# 2025-11-17 01:39:01,687 - INFO -   - Use class weights during training
# 2025-11-17 01:39:01,687 - INFO -   - Collect more diverse examples for high-risk labels
# 2025-11-17 01:39:01,688 - INFO -   - Consider data augmentation techniques
# 2025-11-17 01:39:01,688 - INFO -
# ============================================================

# %% [markdown]
# ## 12. Export Analysis Results

# %%
# Export analysis results to CSV
output_dir = Path('../data/analysis_results')
output_dir.mkdir(exist_ok=True, parents=True)

# Export label statistics
label_stats.to_csv(output_dir / 'label_statistics.csv')
logger.info(f"Exported label statistics to {output_dir / 'label_statistics.csv'}")

# Export risk analysis
risk_analysis.to_csv(output_dir / 'overfitting_risk_analysis.csv', index=False)
logger.info(f"Exported risk analysis to {output_dir / 'overfitting_risk_analysis.csv'}")

# Export formation reports for each label
for label in df_annotations['label'].unique():
    formation_report = create_formation_report(label, df_annotations)
    safe_label = label.replace('/', '_').replace(' ', '_')
    formation_report.to_csv(output_dir / f'formation_{safe_label}.csv', index=False)

logger.info(f"Exported all formation reports to {output_dir}")
logger.info("\nAnalysis complete!")
# Out:
# 2025-11-17 01:39:09,018 - INFO - Exported label statistics to ../data/analysis_results/label_statistics.csv
# 2025-11-17 01:39:09,019 - INFO - Exported risk analysis to ../data/analysis_results/overfitting_risk_analysis.csv
# 2025-11-17 01:39:09,052 - INFO - Exported all formation reports to ../data/analysis_results
# 2025-11-17 01:39:09,052 - INFO -
# Analysis complete!

# %% [markdown]
# ## Search term in wrong label.

# %%
# Serch for specific term in a wrong label
# Example: Find occurrences of the term "java" labeled as 'CITATION'
# This can help identify mislabeling issues in the dataset.
matches = df_annotations[
    (df_annotations['text'] == "java") &
    (df_annotations['label'] == 'CITATION')
]
projects_and_samples = matches[['project', 'sample_id', 'label', 'source_text']].drop_duplicates()
print(projects_and_samples)
# Out:
# Empty DataFrame
# Columns: [project, sample_id, label, source_text]
# Index: []

# %% [markdown]
# #### DELETE A LABEL: this code identifies all projects that have annotations with the label 'XXX' and lists them.

# %%
search_projects_by_label = df_annotations[
    df_annotations['label'] == 'XXX'
]['project'].unique().tolist()
print("Projects with 'XXX' label:")
for project in search_projects_by_label:
    print(f"- {project}")
# Out:
# Projects with 'RUNTIME_PLATFORM' label:
